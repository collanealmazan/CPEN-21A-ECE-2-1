# %% [markdown]
# <a href="https://colab.research.google.com/github/collanealmazan/CPEN-21A-ECE-2-1/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Laboratory 1
# #Welcome to Python Programming

# %%
fname = "Collane J. Almazan"
age = "20 years old"
address = "#262 Woodsite 1, Pasong Buaya 2, Imus Cavite"
print('Name:',fname)
print('Age:',age)
print('Address:',address)
# Out:
# Name: Collane J. Almazan
# Age: 20 years old
# Address: #262 Woodsite 1, Pasong Buaya 2, Imus Cavite
