# %% [markdown]
# <a href="https://colab.research.google.com/github/collanealmazan/CPEN-21A-ECE-2-1/blob/main/Midterm_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Midterm Exam

# %% [markdown]
# ##Problem Statement 1

# %%
fname = "Collane J. Almazan"
studentnumber = "202011735"
age = "20 years old"
birthday = "June 20,2001"
address = "Woodsite 1, Pasong Buaya 2, Imus,Cavite"
course = "BS ECE"
GWA = "1.57"

print('Name:',fname)
print('Student Number:',studentnumber)
print('Age:',age)
print('Birthday:',birthday)
print('Address:',address)
print('Course:',course)
print('Last Sem GWA:',GWA)
# Out:
# Name: Collane J. Almazan
# Student Number: 202011735
# Age: 20 years old
# Birthday: June 20,2001
# Address: Woodsite 1, Pasong Buaya 2, Imus,Cavite
# Course: BS ECE
# Last Sem GWA: 1.57

# %% [markdown]
# ##Problem Statement 2

# %%
n = 4
answ = "Y"
y = answ
a = (2<n) and (n<6)
b = (2<n) or (n==6)
c = not(2<n) or (n==6)
d = not(n<6)
e = (answ=="Y") or (answ=="y")
f = (answ=="Y") and (answ=="y")
g = not(answ=="y")
h = ((2<n) and (n==5+1)) or (answ=="No")
i = ((n==2) and (n==7)) or (answ=="Y")
j = (n==2) and ((n==7) or (answ=="Y"))
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
print(i)
print(j)
# Out:
# True
# True
# False
# False
# True
# False
# True
# False
# True
# False

# %% [markdown]
# ##Problem Statement 3

# %%
x = 2
y = -3
w = 7
z = -10

print(x/y)
print(w/y/x)
print(z/y%x)
print(x%-y*w)
print(x%y)
print(z%w-y/x*5+5)
print(9-x%(2+y))
print(z//w)
print((2+y*2))
print(w/x*2)
# Out:
# -0.6666666666666666
# -1.1666666666666667
# 1.3333333333333335
# 14
# -1
# 16.5
# 9
# -2
# -4
# 7.0
